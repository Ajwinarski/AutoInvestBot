# %%
from fmp_python.fmp import FMP
import urllib.request as req

# proxy = req.ProxyHandler({'http': r'http://WUN1FH:Ajwin113096.@rb-proxy-na.bosch.com:8080'})
# auth = req.HTTPBasicAuthHandler()
# opener = req.build_opener(proxy, auth, req.HTTPHandler)
# req.install_opener(opener)
# conn = req.urlopen('http://financialmodelingprep.com/api/v3/quote/AAPL?apikey=zOWo5NgWst2Ill1VXevneIirrvWYgO3h')
# return_str = conn.read()
# print(return_str)

fmp = FMP(api_key="zOWo5NgWst2Ill1VXevneIirrvWYgO3h", output_format='pandas', write_to_file=True)

fmp.get_quote('AAPL')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File c:\Python38\lib\site-packages\urllib3\connectionpool.py:776, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     775 try:
# --> 776     self._prepare_proxy(conn)
#     777 except (BaseSSLError, OSError, SocketTimeout) as e:
#
# File c:\Python38\lib\site-packages\urllib3\connectionpool.py:1041, in HTTPSConnectionPool._prepare_proxy(self, conn)
#    1035 conn.set_tunnel(
#    1036     scheme=tunnel_scheme,
#    1037     host=self._tunnel_host,
#    1038     port=self.port,
#    1039     headers=self.proxy_headers,
#    1040 )
# -> 1041 conn.connect()
#
# File c:\Python38\lib\site-packages\urllib3\connection.py:635, in HTTPSConnection.connect(self)
# ...
