# %%
import requests

headers = {}
headers['X-MBX-APIKEY'] = 'FccUuDtQTWJLN2c1EECJhti0iwUI202fEQg7BiNTTsh1N3J4SGoFdeTaZTYFEHpX'

resp = requests.get(
    'https://api.binance.us/api/v3/historicalTrades?symbol=BTCUSDT', headers=headers)

print(resp.json())
# Out:
# [{'id': 28311645, 'price': '66216.14000000', 'qty': '0.00003000', 'quoteQty': '1.98648420', 'time': 1709779879398, 'isBuyerMaker': False, 'isBestMatch': True}, {'id': 28311646, 'price': '66216.13000000', 'qty': '0.00021000', 'quoteQty': '13.90538730', 'time': 1709779879667, 'isBuyerMaker': False, 'isBestMatch': True}, {'id': 28311647, 'price': '66216.13000000', 'qty': '0.00021000', 'quoteQty': '13.90538730', 'time': 1709779879968, 'isBuyerMaker': False, 'isBestMatch': True}, {'id': 28311648, 'price': '66216.13000000', 'qty': '0.00021000', 'quoteQty': '13.90538730', 'time': 1709779880263, 'isBuyerMaker': False, 'isBestMatch': True}, {'id': 28311649, 'price': '66216.09000000', 'qty': '0.00021000', 'quoteQty': '13.90537890', 'time': 1709779880974, 'isBuyerMaker': False, 'isBestMatch': True}, {'id': 28311650, 'price': '66216.08000000', 'qty': '0.00021000', 'quoteQty': '13.90537680', 'time': 1709779881196, 'isBuyerMaker': False, 'isBestMatch': True}, {'id': 28311651, 'price': '66216.07000
# ...
