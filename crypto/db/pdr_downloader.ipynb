# %%
from pandas_datareader import data as pdr
import datetime
import matplotlib.pyplot as plt
import yfinance as yf

yf.pdr_override()

# %%
start_date = datetime.datetime(2020, 1, 1)
end_date = datetime.datetime(2021, 1, 1)
ticker = 'BTC'

# %%
# Download Apple's historical stock prices from Yahoo Finance
# data = pdr.get_data_yahoo(ticker, start_date, end_date)

# get full stock data
data = pdr.get_data_yahoo(ticker)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# Print the first 5 rows of the data
print(data.head())
# Out:
#                   Open        High         Low       Close  Adj Close  Volume
# Date
# 2020-10-01  100.000000  100.000000  100.000000  100.000000  96.285774       0
# 2020-10-02  100.000000  100.000000  100.000000  100.000000  96.285774       0
# 2020-10-05  100.029999  100.040001   99.995003   99.995003  96.280960   10725
# 2020-10-06  100.010002  100.029999  100.010002  100.029999  96.314674   10080
# 2020-10-07   99.949997   99.959999   99.919998   99.919998  96.208733    6350

# %%
# save the data
data.to_csv(f'./{ticker}.csv')

# %%
# display
plt.figure(figsize=(20, 10))
# plt.title('Opening Prices from {} to {}'.format(start_date,end_date))
plt.title('Opening Prices')
plt.plot(data['Open'])
plt.show()
